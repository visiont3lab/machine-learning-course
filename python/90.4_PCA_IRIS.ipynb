# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
iris = load_iris()

# %%
X = iris.data

# %%
print(X.shape)
# Out:
# (150, 4)

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ],
#        [ 0.65658877,  0.73016143, -0.17337266, -0.07548102]])

# %%
Z = pca.transform(X)

# %%
Z.shape
# Out:
# (150, 2)

# %%
 plt.scatter(Z[:,0],Z[:,1]); # questo è l'iperpiano in 2 dimensioni che massimizza la varianza

# %%
#lo coloriamo per classi, ponendo come colore=y
y = iris.target

# %%
plt.figure(figsize=(18,10))
plt.scatter(Z[:,0],Z[:,1],c=y);
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
# questa è il modo in cui la PCA può rappresentare i nostri observation in R2, invece che avere R4
