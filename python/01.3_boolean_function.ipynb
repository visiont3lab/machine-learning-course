# %% [markdown]
# ## Boolean

# %%
################ Algebra Booleana ###############

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
variabile = True

# %%
type(variabile)
# Out:
# bool

# %%
True + True
# Out:
# 2

# %%
45*True
# Out:
# 45

# %%
45*False
# Out:
# 0

# %%
50>=40.9999
# Out:
# True

# %%
10//2 == 11//2
# Out:
# True

# %%
# vale anche con le stringhe!! 

'ciao' != 'goodbye'
# Out:
# True

# %%
'ciao' != 'ciao'
# Out:
# False

# %%
#######  AND ##############

# %%
5>6 and 6>5
# Out:
# False

# %%
5>4 and 6>7
# Out:
# False

# %%
#######  OR ##############

# %%
25 >=25  or 31!= 31
# Out:
# True

# %%
21 >21 or 31!=31
# Out:
# False

# %%
28!=28 or 33==33
# Out:
# True

# %%
#######  NOT #############

# %%
#negazione

not 3==3
# Out:
# False

# %%
not 2==3
# Out:
# True

# %% [markdown]
#  IF example

# %%
età=18

if età <18:
    print('sei minorenne')
else:
    print('sei maggiorenne')
# Out:
# sei maggiorenne

# %%
età=18

if età <10:
    print('sei un bimbo')
elif età<=18:
    print('sei un regaz')
elif età<50:
    print('sei un boomer')
else:
    print('bella vecchio! sei anziano')
# Out:
# sei un regaz

# %%
######### caso patente #######

# %%
età=50
patente=False

if età >=18 and patente==True:
    print('puoi guidare finalmente la tua auto da sogno')
elif età >=18 and patente==False:
    print('no patente, no party')
else:
    print('mi dispiace, ritenta quando sarai più grande!!')
# Out:
# no patente, no party

# %% [markdown]
# ### Scrivi le funzioni

# %%
def print_tre_volte():
    print('Ciao')
    print('il mio nome è')
    print('Daniele')

# %%
print_tre_volte()
# Out:
# Ciao
# il mio nome è
# Daniele

# %%
def somma_due_numeri(a,b):
     print('questa funzione somma due numeri:')
     risultato = a + b 
     print('il risultato è  '+str(risultato)) # qui è costruito

# %%
somma_due_numeri(-10.0,3.0)
# Out:
# questa funzione somma due numeri:
# il risultato è  -7.0

# %% [markdown]
# ALLE FUNZIONI POSSIAMO PASSARE DEI VALORI CHIAMATI ARGOMENTI

# %%
def somma_due_numeri(a,b): ## a,b sono argomenti
    #print('questa funzione somma due numeri:')
    risultato = a + b
    return risultato
# OUTPUT DI UNA FUNZIONE è IL VALORE DEL SUO RETURN
# TUTTE LE FUNZIONI HANNO UN RETURN

# %%
somma_due_numeri(2,3)
# Out:
# 5

# %%
ls
# Out:
# formule.py  __pycache__/  sample_data/

# %% [markdown]
# ## INPUT

# %%
x =input()
#x = input('inserire qualcosa   ')
# Out:
# hhj

# %%
type(x)
# Out:
# str

# %%
### PROGRAMMA
print('questo è il mio programma in python')

nome=input('inserire il tuo nome  ') 
print('buon pomeriggio  '+nome+'  spero tu stia imparando tantissimo!')
# Out:
# questo è il mio programma in python
# inserire il tuo nome  tdcyttf
# buon pomeriggio  tdcyttf  spero tu stia imparando tantissimo!

# %%
età = input('quanti anni hai?')
print('Bene!!! dunque hai '+ età + '  anni. Il porssimo anno ne avrai '+ str(int(età)+1))
# Out:
# quanti anni hai?3
# Bene!!! dunque hai 3  anni. Il porssimo anno ne avrai 4

# %% [markdown]
# ## Somma due numeri input

# %%
numero1 = float(input('inserisci un primo numero a tua scelta: '))
numero2 = float(input('inserisci un secondo numero a tua scelta: '))

somma = numero1+numero2
print("il risultato della somma è pari a "+str(somma))
# Out:
# inserisci un primo numero a tua scelta: 3
# inserisci un secondo numero a tua scelta: 4
# il risultato della somma è pari a 7.0
